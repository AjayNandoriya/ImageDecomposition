# %% [markdown]
# <a href="https://colab.research.google.com/github/AjayNandoriya/ImageDecomposition/blob/main/examples/sem_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/AjayNandoriya/ImageDecomposition.git

# %%
import os
import sys
REPO_PATH = r'C:\Users\Dext-PC\source\repos'
sys.path.append(REPO_PATH)
from ImageDecomposition.scripts import sem

# %%
from importlib import reload
reload(sem)
# Out:
# <module 'ImageDecomposition.scripts.sem' from '/content/ImageDecomposition/scripts/sem.py'>

# %%
model = sem.create_model()
print(model.summary())

# %%
sem.train()

# %%
sem.analyse_model()
# Out:
# (4, 512, 512, 4)
# (4, 64, 64, 4)

# %%
import tensorflow as tf

tf.config.list_physical_devices()
